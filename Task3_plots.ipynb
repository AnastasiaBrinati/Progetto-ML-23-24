# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaBrinati/Progetto-ML-23-24/blob/main/Task3_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
task3_FedAvg_100 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.1308, 0.3246, 0.4898, 0.6543, 0.7552, 0.8001, 0.8352, 0.8536, 0.8750, 0.8866],
    'cat_accuracy': [0.1308, 0.3246, 0.4898, 0.6543, 0.7552, 0.8001, 0.8352, 0.8536, 0.8750, 0.8866],
    'topk_accuracy': [0.5753, 0.7525, 0.9141, 0.9668, 0.9785, 0.9833, 0.9854, 0.9881, 0.9906, 0.9899],
    'loss': [2.505817, 2.000379, 1.478582, 1.046845, 0.750211, 0.623913, 0.529405, 0.464159, 0.413245, 0.379287]
}

task3_FedProx_100 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.2901, 0.6465, 0.7844, 0.8335, 0.8619, 0.8735, 0.8920, 0.8982, 0.9058, 0.9137],
    'cat_accuracy': [0.2901, 0.6465, 0.7844, 0.8335, 0.8619, 0.8735, 0.8920, 0.8982, 0.9058, 0.9137],
    'topk_accuracy': [0.7522, 0.9611, 0.9783, 0.9835, 0.9880, 0.9896, 0.9907, 0.9920, 0.9936, 0.9942],
    'loss': [2.081158, 1.047874, 0.701940, 0.556559, 0.466229, 0.419731, 0.368518, 0.342408, 0.307516, 0.284420]
}

task3_QFedAvg_100 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.1736, 0.2191, 0.3004, 0.4299, 0.5358, 0.5787, 0.6509, 0.7234, 0.7767, 0.8106],
    'cat_accuracy': [0.1736, 0.2191, 0.3004, 0.4299, 0.5358, 0.5787, 0.6509, 0.7234, 0.7767, 0.8106],
    'topk_accuracy': [0.6223, 0.6136, 0.7422, 0.8810, 0.9144, 0.9514, 0.9717, 0.9787, 0.9836, 0.9866],
    'loss': [3.052144, 2.138689, 2.040695, 1.813220, 1.393641, 1.139368, 0.912194, 0.800335, 0.690224, 0.611684]
}
task3_FedAvg_10 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.1396, 0.3144, 0.4015, 0.6595, 0.7933, 0.8624, 0.8788, 0.9020, 0.9135, 0.9238],
    'cat_accuracy': [0.1396, 0.3144, 0.4015, 0.6595, 0.7933, 0.8624, 0.8788, 0.9020, 0.9135, 0.9238],
    'topk_accuracy': [0.6178, 0.8005, 0.8854, 0.9510, 0.9725, 0.9874, 0.9893, 0.9929, 0.9940, 0.9942],
    'loss': [3.834348, 1.981152, 1.618643, 1.211388, 0.757223, 0.493698, 0.412210, 0.320931, 0.279641, 0.248362]
}
task3_FedProx_10 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.2111, 0.5874, 0.7182, 0.7933, 0.8403, 0.8488, 0.8767, 0.8907, 0.9002, 0.9140],
    'cat_accuracy': [0.2111, 0.5874, 0.7182, 0.7933, 0.8403, 0.8488, 0.8767, 0.8907, 0.9002, 0.9140],
    'topk_accuracy': [0.7899, 0.9376, 0.9709, 0.9845, 0.9894, 0.9907, 0.9936, 0.9940, 0.9956, 0.9964],
    'loss': [2.065002, 1.274748, 0.862452, 0.654375, 0.518748, 0.462882, 0.398931, 0.352000, 0.322833, 0.288012]
}
task3_QFedAvg_10 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.1633, 0.3720, 0.4776, 0.6038, 0.6566, 0.7180, 0.7522, 0.7768, 0.7934, 0.8206],
    'cat_accuracy': [0.1633, 0.3720, 0.4776, 0.6038, 0.6566, 0.7180, 0.7522, 0.7768, 0.7934, 0.8206],
    'topk_accuracy': [0.6567, 0.8066, 0.9003, 0.9434, 0.9627, 0.9729, 0.9791, 0.9840, 0.9857, 0.9879],
    'loss': [2.810671, 1.824364, 1.510225, 1.189084, 1.028795, 0.871393, 0.775111, 0.687708, 0.634439, 0.569984]
}
task3_FedAvg_5 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.1791, 0.5450, 0.6940, 0.8395, 0.8814, 0.9069, 0.9189, 0.9254, 0.9348, 0.9402],
    'cat_accuracy': [0.1791, 0.5450, 0.6940, 0.8395, 0.8814, 0.9069, 0.9189, 0.9254, 0.9348, 0.9402],
    'topk_accuracy': [0.6482, 0.9487, 0.9768, 0.9855, 0.9902, 0.9922, 0.9935, 0.9939, 0.9954, 0.9962],
    'loss': [3.018399, 1.334101, 0.877807, 0.549155, 0.418776, 0.330590, 0.281983, 0.263710, 0.225585, 0.209047]
}
task3_FedProx_5 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.2039, 0.4199, 0.6056, 0.7671, 0.8279, 0.8617, 0.8819, 0.8988, 0.9077, 0.9183],
    'cat_accuracy': [0.2039, 0.4199, 0.6056, 0.7671, 0.8279, 0.8617, 0.8819, 0.8988, 0.9077, 0.9183],
    'topk_accuracy': [0.6811, 0.8906, 0.9365, 0.9683, 0.9796, 0.9851, 0.9860, 0.9905, 0.9913, 0.9929],
    'loss': [2.506892, 1.593910, 1.178540, 0.764252, 0.567366, 0.453980, 0.385182, 0.337637, 0.311508, 0.275550]
}
task3_QFedAvg_5 = {
    'Epoch': list(range(1, 11)),
    'accuracy': [0.2820, 0.4595, 0.5911, 0.6826, 0.7282, 0.7655, 0.7898, 0.8096, 0.8200, 0.8285],
    'cat_accuracy': [0.2820, 0.4595, 0.5911, 0.6826, 0.7282, 0.7655, 0.7898, 0.8096, 0.8200, 0.8285],
    'topk_accuracy': [0.7107, 0.8653, 0.9333, 0.9648, 0.9770, 0.9802, 0.9832, 0.9848, 0.9860, 0.9868],
    'loss': [2.126181, 1.846541, 1.529425, 1.230552, 1.003095, 0.861222, 0.766520, 0.691888, 0.645418, 0.601402]
}

# %%
import matplotlib.pyplot as plt

# Definizione delle metriche e delle strategie da visualizzare
metrics = ['accuracy', 'cat_accuracy', 'topk_accuracy', 'loss']
strategies = ['task3_FedAvg', 'task3_QFedAvg', 'task3_FedProx']

# Creazione dei subplots
fig, axs = plt.subplots(len(metrics), len(strategies), figsize=(15, 20))

# Looping su ogni metrica per creare i subplots
for i, metric in enumerate(metrics):
    for j, strategy in enumerate(strategies):
        axs[i, j].set_title(f"{metric.replace('_', ' ').title()} - {strategy.split('_')[1]}")
        axs[i, j].set_xlabel('Epoch')
        axs[i, j].set_ylabel(metric)

        # Plotting per ogni numero di client
        for num_clients in [5, 10, 100]:
            strategy_key = f"{strategy}_{num_clients}"
            axs[i, j].plot(eval(strategy_key)['Epoch'], eval(strategy_key)[metric], label=f"{num_clients} clients", linestyle='-', alpha=0.7)

        # Aggiunta della legenda
        axs[i, j].legend()

# Ottimizzazione del layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Definizione delle metriche e delle strategie da visualizzare
metrics = ['accuracy', 'cat_accuracy', 'topk_accuracy', 'loss']
strategies = ['task3_FedAvg', 'task3_QFedAvg', 'task3_FedProx']
num_clients_list = ['5', '10', '100']

# Creazione dei subplots
fig, axs = plt.subplots(len(metrics), len(num_clients_list), figsize=(15, 20))

# Looping su ogni metrica e numero di clienti per creare i subplots
for i, metric in enumerate(metrics):
    for j, num_clients in enumerate(num_clients_list):
        axs[i, j].set_title(f"{metric.replace('_', ' ').title()} - {num_clients} clients")
        axs[i, j].set_xlabel('Epoch')
        axs[i, j].set_ylabel(metric)

        # Plotting per ogni strategia per tutti gli altri casi
        for strategy in strategies:
            strategy_key = f"{strategy}_{num_clients}"
            if metric in eval(strategy_key):
                axs[i, j].plot(eval(strategy_key)['Epoch'], eval(strategy_key)[metric], label=strategy.split('_')[1], linestyle='-')

        # Aggiunta della legenda
        axs[i, j].legend()

# Ottimizzazione del layout
plt.tight_layout()
plt.show()
