# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaBrinati/Progetto-ML-23-24/blob/main/Task2_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
centralizzato = {
    'Epoch': list(range(1, 11)),
    'Categorical Crossentropy Loss': [0.654691, 0.638235, 0.631250, 0.620261, 0.616670, 0.620576, 0.613600, 0.613441, 0.611118, 0.611208],
    'Mean Squared Error': [3.148931, 3.136050, 3.132224, 3.123100, 3.121987, 3.122755, 3.121242, 3.121131, 3.120584, 3.120517],
    'Mean Absolute Percentage Error': [84.439003, 79.750023, 77.709427, 80.765099, 78.399124, 93.155891, 78.342842, 79.306496, 76.801743, 77.030296],
    'Mean Squared Logarithmic Error': [0.158293, 0.154645, 0.152647, 0.148184, 0.147527, 0.147896, 0.147210, 0.147167, 0.146897, 0.146838],
    'R2 Score': [0.179876, 0.183230, 0.184227, 0.186603, 0.186893, 0.186693, 0.187087, 0.187116, 0.187258, 0.187276]
}
task2_FedAvg_10 = {
    'Epoch': list(range(1, 11)),
    'Mean Squared Error': [4.536159, 4.536115, 3.953311, 3.236736, 3.231134, 3.236132, 3.229431, 3.229131, 3.229086, 3.229178],
    'Mean Absolute Percentage Error': [100.017342, 100.027443, 120.919327, 154.915359, 125.122505, 102.653900, 99.786774, 96.671082, 93.692093, 99.611504],
    'Mean Squared Logarithmic Error': [0.487886, 0.487866, 0.337005, 0.167407, 0.166692, 0.169519, 0.166695, 0.166762, 0.166924, 0.166774],
    'Loss (MAE)': [0.934440, 0.934436, 0.857865, 0.691472, 0.683813, 0.685721, 0.678116, 0.676892, 0.676601, 0.677603],
    'R2 Score': [-0.159762, -0.159751, -0.010745, 0.172462, 0.173894, 0.172617, 0.174330, 0.174407, 0.174418, 0.174395]
}

task2_FedProx_10 = {
    'Epoch': list(range(1, 11)),
    'Mean Squared Error': [4.536159, 4.536115, 3.953311, 3.236736, 3.231134, 3.236132, 3.229431, 3.229131, 3.229086, 3.229178],
    'Mean Absolute Percentage Error': [100.017342, 100.027443, 120.919327, 154.915359, 125.122505, 102.653900, 99.786774, 96.671082, 93.692093, 99.611504],
    'Mean Squared Logarithmic Error': [0.487886, 0.487866, 0.337005, 0.167407, 0.166692, 0.169519, 0.166695, 0.166762, 0.166924, 0.166774],
    'Loss (MAE)': [0.934440, 0.934436, 0.857865, 0.691472, 0.683813, 0.685721, 0.678116, 0.676892, 0.676601, 0.677603],
    'R2 Score': [-0.159762, -0.159751, -0.010745, 0.172462, 0.173894, 0.172617, 0.174330, 0.174407, 0.174418, 0.174395]
}

task2_QFedAvg_10 = {
    'Epoch': list(range(1, 11)),
    'Mean Squared Error': [4.536159, 4.536115, 3.953311, 3.236736, 3.231134, 3.236132, 3.229431, 3.229131, 3.229086, 3.229178],
    'Mean Absolute Percentage Error': [100.017342, 100.027443, 120.919327, 154.915359, 125.122505, 102.653900, 99.786774, 96.671082, 93.692093, 99.611504],
    'Mean Squared Logarithmic Error': [0.487886, 0.487866, 0.337005, 0.167407, 0.166692, 0.169519, 0.166695, 0.166762, 0.166924, 0.166774],
    'Loss (MAE)': [0.934440, 0.934436, 0.857865, 0.691472, 0.683813, 0.685721, 0.678116, 0.676892, 0.676601, 0.677603],
    'R2 Score': [-0.159762, -0.159751, -0.010745, 0.172462, 0.173894, 0.172617, 0.174330, 0.174407, 0.174418, 0.174395]
}

task2_FedAvg_100 = {
    'Epoch': list(range(1, 11)),
    'Mean Squared Error': [4.536159, 4.536115, 3.953311, 3.236736, 3.231134, 3.236132, 3.229431, 3.229131, 3.229086, 3.229178],
    'Mean Squared Logarithmic Error': [0.487908, 0.487911, 0.487911, 0.487911, 0.487910, 0.487906, 0.487544, 0.179870, 0.166866, 0.166734],
    'Loss (MAE)': [0.934440, 0.934440, 0.934440, 0.934440, 0.934440, 0.934440, 0.934361, 0.717523, 0.684452, 0.680655]
}

task2_QFedAvg_5 = {
    'Epoch': list(range(1, 11)),
    'R2 Score': [-0.023812, -0.028661, -0.033797, -0.039113, -0.044522, -0.050337, -0.056355, -0.062189, -0.068092, -0.073753],
    'Mean Squared Error': [4.004421, 4.023385, 4.043476, 4.064268, 4.085424, 4.108167, 4.131704, 4.154524, 4.177613, 4.199753],
    'Mean Absolute Percentage Error': [1245.078613, 1170.739014, 1098.969849, 1030.530273, 965.856934, 900.990173, 838.030029, 780.382446, 725.056152, 674.391663],
    'Mean Squared Logarithmic Error': [0.343961, 0.343543, 0.343977, 0.345203, 0.347147, 0.349924, 0.353459, 0.357464, 0.362057, 0.366939],
    'Loss (MAE)': [1.034860, 1.024320, 1.014603, 1.005769, 0.997864, 0.990390, 0.983633, 0.978149, 0.973190, 0.968814]
}

# %%
import matplotlib.pyplot as plt

# Definizione delle metriche e delle strategie da visualizzare
metrics = ['Mean Squared Error', 'Mean Absolute Percentage Error', 'Mean Squared Logarithmic Error', 'R2 Score']
strategies = ['task2_FedAvg', 'task2_QFedAvg', 'task2_FedProx']

# Creazione dei subplots
fig, axs = plt.subplots(len(metrics), len(strategies), figsize=(15, 20))

# Looping su ogni metrica per creare i subplots
for i, metric in enumerate(metrics):
    for j, strategy in enumerate(strategies):
        axs[i, j].set_title(f"{metric} - {strategy.split('_')[1]}")
        axs[i, j].set_xlabel('Epoch')
        axs[i, j].set_ylabel(metric)
        axs[i, j].set_ylim(0, 1)  # Impostazione dell'asse y da 0 a 1

        # Plotting per il risultato centralizzato
        if metric in centralizzato:
            axs[i, j].plot(centralizzato['Epoch'], centralizzato[metric], label='Centralizzato', linestyle='--', color='black')
        else:
            print(f"Metrica '{metric}' non trovata nel dizionario 'centralizzato'.")

        # Plotting per ogni numero di client
        for num_clients in ['5', '10', '100']:
            strategy_key = f"{strategy}_{num_clients}"
            axs[i, j].plot(eval(strategy_key)['Epoch'], eval(strategy_key)[metric], label=f"{num_clients} clients", linestyle='-', alpha=0.7)

        # Aggiunta della legenda
        axs[i, j].legend()

# Ottimizzazione del layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Definizione delle metriche e delle strategie da visualizzare
metrics = ['Mean Squared Error', 'Mean Absolute Percentage Error', 'Mean Squared Logarithmic Error', 'Loss (MAE)', 'R2 Score']
strategies = ['task2_FedAvg', 'task2_QFedAvg', 'task2_FedProx']
num_clients_list = ['5', '10', '100']

# Creazione dei subplots
fig, axs = plt.subplots(len(metrics), len(num_clients_list), figsize=(15, 20))

# Looping su ogni metrica e numero di clienti per creare i subplots
for i, metric in enumerate(metrics):
    for j, num_clients in enumerate(num_clients_list):
        axs[i, j].set_title(f"{metric} - {num_clients} clients")
        axs[i, j].set_xlabel('Epoch')
        axs[i, j].set_ylabel(metric)

        # Plotting per il risultato centralizzato
        if metric in centralizzato:
            axs[i, j].plot(centralizzato['Epoch'], centralizzato[metric], label='Centralizzato', linestyle='--', color='black')


        # Plotting per ogni strategia per tutti gli altri casi
        for strategy in strategies:
            strategy_key = f"{strategy}_{num_clients}"
            if metric in eval(strategy_key):
                axs[i, j].plot(eval(strategy_key)['Epoch'], eval(strategy_key)[metric], label=strategy.split('_')[1], linestyle='-')

        # Aggiunta della legenda
        axs[i, j].legend()

# Ottimizzazione del layout
plt.tight_layout()
plt.show()
